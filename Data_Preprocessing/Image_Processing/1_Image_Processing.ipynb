# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ## Read a color image

# %%
img = cv2.imread('galaxies.jpg',1)

# %%
plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (1228, 1280, 3)

# %% [markdown]
# ## Convert the image to gray-scale

# %%
img_converted = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img_converted)
plt.show()

# %%
img_converted.shape
# Out:
# (1228, 1280)

# %% [markdown]
# ## Read the image directly in gray-scale

# %%
img_gray = cv2.imread('galaxies.jpg',0) # note the 0 instead of 1

# %%
plt.imshow(img_gray)
plt.show()

# %% [markdown]
# ## Save the image

# %%
cv2.imwrite('gray_image.jpg', img_gray)# params=None
# Out:
# True

# %% [markdown]
# ## Crop the image

# %%
plt.imshow(img[0:200,0:200])
plt.show()

# %%
img.shape
# Out:
# (1228, 1280, 3)

# %%
img[0:200,0:200].shape
# Out:
# (200, 200, 3)

# %% [markdown]
# ## Resize the image

# %%
image_100x100 = cv2.resize(img_gray, (100, 100))

# %%
plt.imshow(image_100x100)
plt.show()

# %%
image_100x100.shape
# Out:
# (100, 100)

# %%
image_100x100
# Out:
# array([[ 19,  18,  17, ...,  13,  16,  16],
#        [ 16,  16,  19, ...,  15,  16,  16],
#        [ 19,  16,  16, ...,  16,  13,  17],
#        ...,
#        [ 19,  19,  21, ...,  19,  21,  22],
#        [ 19,  21,  20, ...,  14,  21,  21],
#        [ 20,  22,  24, ...,  14,  45, 113]], dtype=uint8)
